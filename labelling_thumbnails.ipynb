# %% [markdown]
# Labelling good or bad for each thumbnails. Code is generated by our group members.

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('final_yt_data.csv')

# %%
data['Label'] = 'good'

# %%
data.to_csv('good_org_label.csv')
